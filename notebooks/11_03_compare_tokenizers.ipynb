# %%
from pathlib import Path

PROJECT_ROOT = Path("/workspace/tiny-llm-from-scratch")

print("=" * 60)
print("TinyGPT - Phase 11.01")
print("Build BPE Tokenizer")
print("=" * 60)

print("Project Root :", PROJECT_ROOT)
print("Exists       :", PROJECT_ROOT.exists())
# Out:
# ============================================================
# TinyGPT - Phase 11.01
# Build BPE Tokenizer
# ============================================================
# Project Root : /workspace/tiny-llm-from-scratch
# Exists       : True

# %%
from pathlib import Path

dataset = PROJECT_ROOT / "datasets" / "processed" / "merged" / "merged_dataset.json"

print(dataset)
print(dataset.exists())
# Out:
# /workspace/tiny-llm-from-scratch/datasets/processed/merged/merged_dataset.json
# True
